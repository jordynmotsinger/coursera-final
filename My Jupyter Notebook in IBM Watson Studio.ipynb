# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Jordyn M.__
# Project Manager

# %% [markdown]
# _I am interested in data science because there is a lot of opportunity. The field is still new, which allows for new opportunities._

# %% [markdown]
# ### A simple calculation to show how this can be completed in Jupyter Notebook

# %%
3 + 7
# Out:
# 10

# %% [markdown]
# 1. I enjoyed this class
# 2. I am looking forward to learning more

# %% [markdown]
# - I hope to gain data analytic experience
# - I want to learn SQL

# %% [markdown]
# <fontcolor=red
